# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import skimage.io as io
import os
from IPython.display import HTML

# %matplotlib inline

# %%
current_dir = os.getcwd()
#print(current_dir)

t1_file = "CHB/CHB_train_Case01/CHB_train_Case01_T1.nhdr"
t2_file = "CHB/CHB_train_Case01/CHB_train_Case01_T2.nhdr"
flair_file = "CHB/CHB_train_Case01/CHB_train_Case01_FLAIR.nhdr"
lesion_file = "CHB/CHB_train_Case01/CHB_train_Case01_lesion.nhdr"

# %%
file_name = t1_file

img = io.imread(current_dir+"/"+file_name, plugin='simpleitk')
print(type(img),img.shape)

x = img.shape[0]
# Out:
# <class 'numpy.ndarray'> (512, 512, 512)

# %%
file_name = t1_file
img_t1 = io.imread(current_dir+"/"+file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img_t1[256,:,:],cmap="gray")

file_name = t2_file
img_t2 = io.imread(current_dir+"/"+file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img_t2[256,:,:],cmap="gray")

file_name = flair_file
img_flair = io.imread(current_dir+"/"+file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img_flair[256,:,:],cmap="gray")

file_name = lesion_file
img_lesion = io.imread(current_dir+"/"+file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img_lesion[256,:,:],cmap="gray")

# %%
img_t1_coronal = img_t1.transpose([1,0,2])
img_t2_coronal = img_t2.transpose([1,0,2])
img_flair_coronal = img_flair.transpose([1,0,2])
img_lesion_coronal = img_lesion.transpose([1,0,2])

fig = plt.figure()
plot_obj = plt.imshow(img_t1_coronal[256,:,:],cmap="gray")

fig = plt.figure()
plot_obj = plt.imshow(img_t2_coronal[256,:,:],cmap="gray")

fig = plt.figure()
plot_obj = plt.imshow(img_flair_coronal[256,:,:],cmap="gray")

fig = plt.figure()
plot_obj = plt.imshow(img_lesion_coronal[256,:,:],cmap="gray")

# %%
img_t1 = img_t1.transpose([2,1,0])
img_t2 = img_t2.transpose([2,1,0])
img_flair = img_flair.transpose([2,1,0])
img_lesion = img_lesion.transpose([2,1,0])

fig = plt.figure()
plot_obj = plt.imshow(img_t1[256,:,:],cmap="gray")

fig = plt.figure()
plot_obj = plt.imshow(img_t2[256,:,:],cmap="gray")

fig = plt.figure()
plot_obj = plt.imshow(img_flair[256,:,:],cmap="gray")

fig = plt.figure()
plot_obj = plt.imshow(img_lesion[256,:,:],cmap="gray")
