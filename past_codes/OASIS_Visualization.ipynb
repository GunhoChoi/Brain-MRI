# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import skimage.io as io
import os
from IPython.display import HTML

# %matplotlib inline

idx = 90

# %% [markdown]
# ## FSL_SEG folder

# %%
seg_file = '/home/ubuntu/Documents/MRI_Data/OASIS/disc1/OAS1_0001_MR1/FSL_SEG/OAS1_0001_MR1_mpr_n4_anon_111_t88_masked_gfc_fseg.hdr'

file_name = seg_file

img = io.imread(file_name, plugin='simpleitk')
print(img.shape)
fig = plt.figure()

plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()

img[img>0]=1
plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()
# Out:
# (176, 208, 176)

# %% [markdown]
# ## Processed - MPRAGE - SUBJ_111

# %%
subj_111 = '/home/ubuntu/Documents/MRI_Data/OASIS/disc1/OAS1_0001_MR1/PROCESSED/MPRAGE/SUBJ_111/OAS1_0001_MR1_mpr_n4_anon_sbj_111.hdr'

file_name = subj_111

img = io.imread(file_name, plugin='simpleitk')
fig = plt.figure()

plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()

print(img.shape)
# Out:
# (160, 256, 256)

# %% [markdown]
# ## Processed - MPRAGE - T88_111

# %%
t88_111 = '/home/ubuntu/Documents/MRI_Data/OASIS/disc1/OAS1_0001_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0001_MR1_mpr_n4_anon_111_t88_gfc.hdr'
t88_111_masked ='/home/ubuntu/Documents/MRI_Data/OASIS/disc1/OAS1_0001_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0001_MR1_mpr_n4_anon_111_t88_masked_gfc.hdr'

file_name = t88_111

img = io.imread(file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()


file_name = t88_111_masked

img = io.imread(file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()

img[img>0]=1
plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()

print(img.shape)
# Out:
# (176, 208, 176)

# %%
## RAW 

mpr1 = '/home/ubuntu/Documents/MRI_Data/OASIS/disc1/OAS1_0001_MR1/RAW/OAS1_0001_MR1_mpr-1_anon.hdr'
mpr2 = '/home/ubuntu/Documents/MRI_Data/OASIS/disc1/OAS1_0001_MR1/RAW/OAS1_0001_MR1_mpr-2_anon.hdr'
mpr3 = '/home/ubuntu/Documents/MRI_Data/OASIS/disc1/OAS1_0001_MR1/RAW/OAS1_0001_MR1_mpr-3_anon.hdr'
mpr4 = '/home/ubuntu/Documents/MRI_Data/OASIS/disc1/OAS1_0001_MR1/RAW/OAS1_0001_MR1_mpr-4_anon.hdr'

file_name = mpr1

img = io.imread(file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()


file_name = mpr2

img = io.imread(file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()


file_name = mpr3

img = io.imread(file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()


file_name = mpr4

img = io.imread(file_name, plugin='simpleitk')
fig = plt.figure()
plot_obj = plt.imshow(img[idx,:,:],cmap="gray")
plt.show()

print(img.shape)
# Out:
# (128, 256, 256)
